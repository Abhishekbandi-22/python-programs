# %%
def eligibility(age, percentage):
    if age >= 18 and percentage >= 60:
        return "Eligible ."
    else:
        return "Not Eligible."
age = int(input("Enter age: "))
percentage = float(input("Enter percentage: "))
result = eligibility(age, percentage)
print(result)
# Out:
# Enter age:  19
# Enter percentage:  55
# Not Eligible.
