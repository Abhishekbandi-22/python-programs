# %%
name = input("Enter Intern Name: ")

age = int(input("Enter Age: "))  # Type casting to integer

email = input("Enter Email ID: ")

contact = input("Enter Contact Number: ")

percentage = float(input("Enter Graduation Percentage: "))  # Type casting to float

if age < 18:
    print("Rejection: Age must be 18 or above")
elif percentage < 60:
    print("Rejection: Graduation Percentage must be 60% or above")
elif not contact.isdigit() or len(contact) != 10:
    print("Rejection: Contact number must contain exactly 10 digits")
else:
    print("Intern Eligible for Internship")
# Out:
# Enter Intern Name:  abhi
# Enter Age:  17
# Enter Email ID:  abhishekbandi935@gmail.com
# Enter Contact Number:  9901063591
# Enter Graduation Percentage:  50
# Rejection: Age must be 18 or above
